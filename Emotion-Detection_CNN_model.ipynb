# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Import necessary libraries and packages

# %%
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten,BatchNormalization
from keras.layers import Conv2D,MaxPooling2D
from keras.optimizers import RMSprop,SGD,Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
# Out:
# 2024-04-21 14:06:28.648667: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-21 14:06:28.648781: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-21 14:06:28.769632: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# **Lets' create checkpoints folder where we can store model wieights**

# %%
cd /kaggle/working
# Out:
# /kaggle/working

# %%
ls -lrt
# Out:
# total 8
# -rw-r--r-- 1 root root    2 Apr 21 14:05 state.db
# drwxr-xr-x 2 root root 4096 Apr 21 14:05 checkpoints/

# %%
mkdir checkpoints
# Out:
# mkdir: cannot create directory 'checkpoints': File exists

# %%
ls -lrt
# Out:
# total 8
# -rw-r--r-- 1 root root    2 Apr  7 15:56 state.db
# drwxr-xr-x 2 root root 4096 Apr  7 15:56 checkpoints/

# %%
cd checkpoints
# Out:
# /kaggle/working/checkpoints

# %%
pwd
# Out:
# '/kaggle/working/checkpoints'

# %% [markdown]
# **Set the training directory path to import training datset**

# %%
train_data_dir='/kaggle/input/emotion-detection-fer/train/'

# %% [markdown]
# # Image data augmentation
#
# **Image data augmentation use to create variations in existing images by applying image augmentation properties like rotation, zoom, flip etc , this will increase train dataset size and will also help to improve accuracy of model by adding variation in existing dataset.
# We are using Keras ImageDataGenerator to augment train dataset.**

# %%
train_data_dir='/kaggle/input/emotion-detection-fer/train/'
train_datagen = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.3,
    zoom_range=0.3,
    width_shift_range=0.4,
    height_shift_range=0.4,
    horizontal_flip=True,
    fill_mode='nearest'
     )

# %%
train_generator = train_datagen.flow_from_directory(
 train_data_dir,
 color_mode='rgb',
 target_size=(255,255),
 batch_size=4,
 class_mode='categorical',
 subset='training',
 shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.

# %% [markdown]
# # Function to print model layers and set trainable = false for all layers of model.

# %%
def model_layers(model_conv):

  model_conv.trainable = False

  for layer in model_conv.layers:
    print(layer.name,layer.trainable)

# %% [markdown]
# # Function to fine-tune pre-trained model layers
#
# **In this function we are accepting model (convbase) and no. of layers which we want to fine tune (fine_tune).**

# %%
def set_trainable(convbase, fine_tune):

  convbase.trainable = True

  #set_trainable = True
  for layer in convbase.layers[:fine_tune]:
    layer.trainable = False



  return convbase

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
import keras
print(keras.__version__)
# Out:
# 2.15.0

# %% [markdown]
# # Test and validation image data
#
# **Let's set path for validation and test image dataset and import test , validation image data**

# %%
test_data_dir='/kaggle/input/emotion-detection-fer/test/'
test_datagen = ImageDataGenerator(
validation_split=0.2)


val_datagen = ImageDataGenerator(
    validation_split=0.2)

test_generator = test_datagen.flow_from_directory(test_data_dir,color_mode='rgb',
                                                       target_size=(255, 255),
                                                       batch_size=1,
                                                       class_mode='categorical',
                                                       subset='training',
                                                       shuffle=True)

validation_generator = val_datagen.flow_from_directory(test_data_dir,color_mode='rgb',
                                                       target_size=(255, 255),
                                                       batch_size=4,
                                                       class_mode='categorical',
                                                       subset='validation',
                                                       shuffle=True)
# Out:
# Found 5746 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %% [markdown]
# # Create list of output class labels

# %%
class_labels=['Angry', 'disgusted', 'fearful', 'Happy','Neutral','Sad','Surprise']

l ={0:'Angry', 1:'disgusted', 2:'fearful', 3:'Happy', 4:'Neutral',5:'Sad', 6:'Surprise'}

# %% [markdown]
# # Let's import EfficientNetV2M model
#
# EfficientNetV2M model is CNN model which is pre-trained on imagenet dataset.
# We will import fully connected layers except output layer by setting inlude_top=False, downloading imagenet wieights for efficientNet model and setting input shape of size (255, 255, 3).

# %%
conv_base_EffiecientNetv2M =tf.keras.applications.efficientnet_v2.EfficientNetV2M(
    include_top=False,
    weights='imagenet',
    input_shape=(255, 255, 3)
    
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 1s 0us/step

# %% [markdown]
# # Print no. of layers of EfficientNetV2M model

# %%
print("Number of layers in the Inception base model: ", len(conv_base_EffiecientNetv2M.layers))
# Out:
# Number of layers in the Inception base model:  740

# %% [markdown]
# # Fine tuning EfficientNetV2M model
#
# In fine tuning pre-trained model we decides how many layers of EffiecieNetV2M model we can use for traning on emotion detection dataset.
# Here, I have tested model by freezing diffenet no. of layers but i got more acuracy when I tried to use all layers to train on Emotion detection datset.

# %%
conv_base_EffiecientNetv2M = set_trainable(conv_base_EffiecientNetv2M, 0)

for layer in conv_base_EffiecientNetv2M.layers:
    print(layer.name,layer.trainable)
# Out:
# input_1 True
# rescaling True
# stem_conv True
# stem_bn True
# stem_activation True
# block1a_project_conv True
# block1a_project_bn True
# block1a_project_activation True
# block1a_add True
# block1b_project_conv True
# block1b_project_bn True
# block1b_project_activation True
# block1b_drop True
# block1b_add True
# block1c_project_conv True
# block1c_project_bn True
# block1c_project_activation True
# block1c_drop True
# block1c_add True
# block2a_expand_conv True
# block2a_expand_bn True
# block2a_expand_activation True
# block2a_project_conv True
# block2a_project_bn True
# block2b_expand_conv True
# block2b_expand_bn True
# block2b_expand_activation True
# block2b_project_conv True
# block2b_project_bn True
# block2b_drop True
# block2b_add True
# block2c_expand_conv True
# block2c_expand_bn True
# block2c_expand_activation True
# block2c_project_conv True
# block2c_project_bn True
# block2c_drop True
# block2c_add True
# block2d_expand_conv True
# block2d_expand_bn True
# block2d_expand_activation True
# block2d_project_conv True
# block2d_project_bn True
# block2d_drop True
# block2d_add True
# block2e_expand_conv True
# block2e_expand_bn True
# block2e_expand_activation True
# block2e_project_conv True
# block2e_project_bn True
# block2e_drop True
# block2e_add True
# block3a_expand_conv True
# block3a_expand_bn True
# block3a_expand_activation True
# block3a_project_conv True
# block3a_project_bn True
# block3b_expand_conv True
# block3b_expand_bn True
# block3b_expand_activation True
# block3b_project_conv True
# block3b_project_bn True
# block3b_drop True
# block3b_add True
# block3c_expand_conv True
# block3c_expand_bn True
# block3c_expand_activation True
# block3c_project_conv True
# block3c_project_bn True
# block3c_drop True
# block3c_add True
# block3d_expand_conv True
# block3d_expand_bn True
# block3d_expand_activation True
# block3d_project_conv True
# block3d_project_bn True
# block3d_drop True
# block3d_add True
# block3e_expand_conv True
# block3e_expand_bn True
# block3e_expand_activation True
# block3e_project_conv True
# block3e_project_bn True
# block3e_drop True
# block3e_add True
# block4a_expand_conv True
# block4a_expand_bn True
# block4a_expand_activation True
# block4a_dwconv2 True
# block4a_bn True
# block4a_activation True
# block4a_se_squeeze True
# block4a_se_reshape True
# block4a_se_reduce True
# block4a_se_expand True
# block4a_se_excite True
# block4a_project_conv True
# block4a_project_bn True
# block4b_expand_conv True
# block4b_expand_bn True
# block4b_expand_activation True
# block4b_dwconv2 True
# block4b_bn True
# block4b_activation True
# block4b_se_squeeze True
# block4b_se_reshape True
# block4b_se_reduce True
# block4b_se_expand True
# block4b_se_excite True
# block4b_project_conv True
# block4b_project_bn True
# block4b_drop True
# block4b_add True
# block4c_expand_conv True
# block4c_expand_bn True
# block4c_expand_activation True
# block4c_dwconv2 True
# block4c_bn True
# block4c_activation True
# block4c_se_squeeze True
# block4c_se_reshape True
# block4c_se_reduce True
# block4c_se_expand True
# block4c_se_excite True
# block4c_project_conv True
# block4c_project_bn True
# block4c_drop True
# block4c_add True
# block4d_expand_conv True
# block4d_expand_bn True
# block4d_expand_activation True
# block4d_dwconv2 True
# block4d_bn True
# block4d_activation True
# block4d_se_squeeze True
# block4d_se_reshape True
# block4d_se_reduce True
# block4d_se_expand True
# block4d_se_excite True
# block4d_project_conv True
# block4d_project_bn True
# block4d_drop True
# block4d_add True
# block4e_expand_conv True
# block4e_expand_bn True
# block4e_expand_activation True
# block4e_dwconv2 True
# block4e_bn True
# block4e_activation True
# block4e_se_squeeze True
# block4e_se_reshape True
# block4e_se_reduce True
# block4e_se_expand True
# block4e_se_excite True
# block4e_project_conv True
# block4e_project_bn True
# block4e_drop True
# block4e_add True
# block4f_expand_conv True
# block4f_expand_bn True
# block4f_expand_activation True
# block4f_dwconv2 True
# block4f_bn True
# block4f_activation True
# block4f_se_squeeze True
# block4f_se_reshape True
# block4f_se_reduce True
# block4f_se_expand True
# block4f_se_excite True
# block4f_project_conv True
# block4f_project_bn True
# block4f_drop True
# block4f_add True
# block4g_expand_conv True
# block4g_expand_bn True
# block4g_expand_activation True
# block4g_dwconv2 True
# block4g_bn True
# block4g_activation True
# block4g_se_squeeze True
# block4g_se_reshape True
# block4g_se_reduce True
# block4g_se_expand True
# block4g_se_excite True
# block4g_project_conv True
# block4g_project_bn True
# block4g_drop True
# block4g_add True
# block5a_expand_conv True
# block5a_expand_bn True
# block5a_expand_activation True
# block5a_dwconv2 True
# block5a_bn True
# block5a_activation True
# block5a_se_squeeze True
# block5a_se_reshape True
# block5a_se_reduce True
# block5a_se_expand True
# block5a_se_excite True
# block5a_project_conv True
# block5a_project_bn True
# block5b_expand_conv True
# block5b_expand_bn True
# block5b_expand_activation True
# block5b_dwconv2 True
# block5b_bn True
# block5b_activation True
# block5b_se_squeeze True
# block5b_se_reshape True
# block5b_se_reduce True
# block5b_se_expand True
# block5b_se_excite True
# block5b_project_conv True
# block5b_project_bn True
# block5b_drop True
# block5b_add True
# block5c_expand_conv True
# block5c_expand_bn True
# block5c_expand_activation True
# block5c_dwconv2 True
# block5c_bn True
# block5c_activation True
# block5c_se_squeeze True
# block5c_se_reshape True
# block5c_se_reduce True
# block5c_se_expand True
# block5c_se_excite True
# block5c_project_conv True
# block5c_project_bn True
# block5c_drop True
# block5c_add True
# block5d_expand_conv True
# block5d_expand_bn True
# block5d_expand_activation True
# block5d_dwconv2 True
# block5d_bn True
# block5d_activation True
# block5d_se_squeeze True
# block5d_se_reshape True
# block5d_se_reduce True
# block5d_se_expand True
# block5d_se_excite True
# block5d_project_conv True
# block5d_project_bn True
# block5d_drop True
# block5d_add True
# block5e_expand_conv True
# block5e_expand_bn True
# block5e_expand_activation True
# block5e_dwconv2 True
# block5e_bn True
# block5e_activation True
# block5e_se_squeeze True
# block5e_se_reshape True
# block5e_se_reduce True
# block5e_se_expand True
# block5e_se_excite True
# block5e_project_conv True
# block5e_project_bn True
# block5e_drop True
# block5e_add True
# block5f_expand_conv True
# block5f_expand_bn True
# block5f_expand_activation True
# block5f_dwconv2 True
# block5f_bn True
# block5f_activation True
# block5f_se_squeeze True
# block5f_se_reshape True
# block5f_se_reduce True
# block5f_se_expand True
# block5f_se_excite True
# block5f_project_conv True
# block5f_project_bn True
# block5f_drop True
# block5f_add True
# block5g_expand_conv True
# block5g_expand_bn True
# block5g_expand_activation True
# block5g_dwconv2 True
# block5g_bn True
# block5g_activation True
# block5g_se_squeeze True
# block5g_se_reshape True
# block5g_se_reduce True
# block5g_se_expand True
# block5g_se_excite True
# block5g_project_conv True
# block5g_project_bn True
# block5g_drop True
# block5g_add True
# block5h_expand_conv True
# block5h_expand_bn True
# block5h_expand_activation True
# block5h_dwconv2 True
# block5h_bn True
# block5h_activation True
# block5h_se_squeeze True
# block5h_se_reshape True
# block5h_se_reduce True
# block5h_se_expand True
# block5h_se_excite True
# block5h_project_conv True
# block5h_project_bn True
# block5h_drop True
# block5h_add True
# block5i_expand_conv True
# block5i_expand_bn True
# block5i_expand_activation True
# block5i_dwconv2 True
# block5i_bn True
# block5i_activation True
# block5i_se_squeeze True
# block5i_se_reshape True
# block5i_se_reduce True
# block5i_se_expand True
# block5i_se_excite True
# block5i_project_conv True
# block5i_project_bn True
# block5i_drop True
# block5i_add True
# block5j_expand_conv True
# block5j_expand_bn True
# block5j_expand_activation True
# block5j_dwconv2 True
# block5j_bn True
# block5j_activation True
# block5j_se_squeeze True
# block5j_se_reshape True
# block5j_se_reduce True
# block5j_se_expand True
# block5j_se_excite True
# block5j_project_conv True
# block5j_project_bn True
# block5j_drop True
# block5j_add True
# block5k_expand_conv True
# block5k_expand_bn True
# block5k_expand_activation True
# block5k_dwconv2 True
# block5k_bn True
# block5k_activation True
# block5k_se_squeeze True
# block5k_se_reshape True
# block5k_se_reduce True
# block5k_se_expand True
# block5k_se_excite True
# block5k_project_conv True
# block5k_project_bn True
# block5k_drop True
# block5k_add True
# block5l_expand_conv True
# block5l_expand_bn True
# block5l_expand_activation True
# block5l_dwconv2 True
# block5l_bn True
# block5l_activation True
# block5l_se_squeeze True
# block5l_se_reshape True
# block5l_se_reduce True
# block5l_se_expand True
# block5l_se_excite True
# block5l_project_conv True
# block5l_project_bn True
# block5l_drop True
# block5l_add True
# block5m_expand_conv True
# block5m_expand_bn True
# block5m_expand_activation True
# block5m_dwconv2 True
# block5m_bn True
# block5m_activation True
# block5m_se_squeeze True
# block5m_se_reshape True
# block5m_se_reduce True
# block5m_se_expand True
# block5m_se_excite True
# block5m_project_conv True
# block5m_project_bn True
# block5m_drop True
# block5m_add True
# block5n_expand_conv True
# block5n_expand_bn True
# block5n_expand_activation True
# block5n_dwconv2 True
# block5n_bn True
# block5n_activation True
# block5n_se_squeeze True
# block5n_se_reshape True
# block5n_se_reduce True
# block5n_se_expand True
# block5n_se_excite True
# block5n_project_conv True
# block5n_project_bn True
# block5n_drop True
# block5n_add True
# block6a_expand_conv True
# block6a_expand_bn True
# block6a_expand_activation True
# block6a_dwconv2 True
# block6a_bn True
# block6a_activation True
# block6a_se_squeeze True
# block6a_se_reshape True
# block6a_se_reduce True
# block6a_se_expand True
# block6a_se_excite True
# block6a_project_conv True
# block6a_project_bn True
# block6b_expand_conv True
# block6b_expand_bn True
# block6b_expand_activation True
# block6b_dwconv2 True
# block6b_bn True
# block6b_activation True
# block6b_se_squeeze True
# block6b_se_reshape True
# block6b_se_reduce True
# block6b_se_expand True
# block6b_se_excite True
# block6b_project_conv True
# block6b_project_bn True
# block6b_drop True
# block6b_add True
# block6c_expand_conv True
# block6c_expand_bn True
# block6c_expand_activation True
# block6c_dwconv2 True
# block6c_bn True
# block6c_activation True
# block6c_se_squeeze True
# block6c_se_reshape True
# block6c_se_reduce True
# block6c_se_expand True
# block6c_se_excite True
# block6c_project_conv True
# block6c_project_bn True
# block6c_drop True
# block6c_add True
# block6d_expand_conv True
# block6d_expand_bn True
# block6d_expand_activation True
# block6d_dwconv2 True
# block6d_bn True
# block6d_activation True
# block6d_se_squeeze True
# block6d_se_reshape True
# block6d_se_reduce True
# block6d_se_expand True
# block6d_se_excite True
# block6d_project_conv True
# block6d_project_bn True
# block6d_drop True
# block6d_add True
# block6e_expand_conv True
# block6e_expand_bn True
# block6e_expand_activation True
# block6e_dwconv2 True
# block6e_bn True
# block6e_activation True
# block6e_se_squeeze True
# block6e_se_reshape True
# block6e_se_reduce True
# block6e_se_expand True
# block6e_se_excite True
# block6e_project_conv True
# block6e_project_bn True
# block6e_drop True
# block6e_add True
# block6f_expand_conv True
# block6f_expand_bn True
# block6f_expand_activation True
# block6f_dwconv2 True
# block6f_bn True
# block6f_activation True
# block6f_se_squeeze True
# block6f_se_reshape True
# block6f_se_reduce True
# block6f_se_expand True
# block6f_se_excite True
# block6f_project_conv True
# block6f_project_bn True
# block6f_drop True
# block6f_add True
# block6g_expand_conv True
# block6g_expand_bn True
# block6g_expand_activation True
# block6g_dwconv2 True
# block6g_bn True
# block6g_activation True
# block6g_se_squeeze True
# block6g_se_reshape True
# block6g_se_reduce True
# block6g_se_expand True
# block6g_se_excite True
# block6g_project_conv True
# block6g_project_bn True
# block6g_drop True
# block6g_add True
# block6h_expand_conv True
# block6h_expand_bn True
# block6h_expand_activation True
# block6h_dwconv2 True
# block6h_bn True
# block6h_activation True
# block6h_se_squeeze True
# block6h_se_reshape True
# block6h_se_reduce True
# block6h_se_expand True
# block6h_se_excite True
# block6h_project_conv True
# block6h_project_bn True
# block6h_drop True
# block6h_add True
# block6i_expand_conv True
# block6i_expand_bn True
# block6i_expand_activation True
# block6i_dwconv2 True
# block6i_bn True
# block6i_activation True
# block6i_se_squeeze True
# block6i_se_reshape True
# block6i_se_reduce True
# block6i_se_expand True
# block6i_se_excite True
# block6i_project_conv True
# block6i_project_bn True
# block6i_drop True
# block6i_add True
# block6j_expand_conv True
# block6j_expand_bn True
# block6j_expand_activation True
# block6j_dwconv2 True
# block6j_bn True
# block6j_activation True
# block6j_se_squeeze True
# block6j_se_reshape True
# block6j_se_reduce True
# block6j_se_expand True
# block6j_se_excite True
# block6j_project_conv True
# block6j_project_bn True
# block6j_drop True
# block6j_add True
# block6k_expand_conv True
# block6k_expand_bn True
# block6k_expand_activation True
# block6k_dwconv2 True
# block6k_bn True
# block6k_activation True
# block6k_se_squeeze True
# block6k_se_reshape True
# block6k_se_reduce True
# block6k_se_expand True
# block6k_se_excite True
# block6k_project_conv True
# block6k_project_bn True
# block6k_drop True
# block6k_add True
# block6l_expand_conv True
# block6l_expand_bn True
# block6l_expand_activation True
# block6l_dwconv2 True
# block6l_bn True
# block6l_activation True
# block6l_se_squeeze True
# block6l_se_reshape True
# block6l_se_reduce True
# block6l_se_expand True
# block6l_se_excite True
# block6l_project_conv True
# block6l_project_bn True
# block6l_drop True
# block6l_add True
# block6m_expand_conv True
# block6m_expand_bn True
# block6m_expand_activation True
# block6m_dwconv2 True
# block6m_bn True
# block6m_activation True
# block6m_se_squeeze True
# block6m_se_reshape True
# block6m_se_reduce True
# block6m_se_expand True
# block6m_se_excite True
# block6m_project_conv True
# block6m_project_bn True
# block6m_drop True
# block6m_add True
# block6n_expand_conv True
# block6n_expand_bn True
# block6n_expand_activation True
# block6n_dwconv2 True
# block6n_bn True
# block6n_activation True
# block6n_se_squeeze True
# block6n_se_reshape True
# block6n_se_reduce True
# block6n_se_expand True
# block6n_se_excite True
# block6n_project_conv True
# block6n_project_bn True
# block6n_drop True
# block6n_add True
# block6o_expand_conv True
# block6o_expand_bn True
# block6o_expand_activation True
# block6o_dwconv2 True
# block6o_bn True
# block6o_activation True
# block6o_se_squeeze True
# block6o_se_reshape True
# block6o_se_reduce True
# block6o_se_expand True
# block6o_se_excite True
# block6o_project_conv True
# block6o_project_bn True
# block6o_drop True
# block6o_add True
# block6p_expand_conv True
# block6p_expand_bn True
# block6p_expand_activation True
# block6p_dwconv2 True
# block6p_bn True
# block6p_activation True
# block6p_se_squeeze True
# block6p_se_reshape True
# block6p_se_reduce True
# block6p_se_expand True
# block6p_se_excite True
# block6p_project_conv True
# block6p_project_bn True
# block6p_drop True
# block6p_add True
# block6q_expand_conv True
# block6q_expand_bn True
# block6q_expand_activation True
# block6q_dwconv2 True
# block6q_bn True
# block6q_activation True
# block6q_se_squeeze True
# block6q_se_reshape True
# block6q_se_reduce True
# block6q_se_expand True
# block6q_se_excite True
# block6q_project_conv True
# block6q_project_bn True
# block6q_drop True
# block6q_add True
# block6r_expand_conv True
# block6r_expand_bn True
# block6r_expand_activation True
# block6r_dwconv2 True
# block6r_bn True
# block6r_activation True
# block6r_se_squeeze True
# block6r_se_reshape True
# block6r_se_reduce True
# block6r_se_expand True
# block6r_se_excite True
# block6r_project_conv True
# block6r_project_bn True
# block6r_drop True
# block6r_add True
# block7a_expand_conv True
# block7a_expand_bn True
# block7a_expand_activation True
# block7a_dwconv2 True
# block7a_bn True
# block7a_activation True
# block7a_se_squeeze True
# block7a_se_reshape True
# block7a_se_reduce True
# block7a_se_expand True
# block7a_se_excite True
# block7a_project_conv True
# block7a_project_bn True
# block7b_expand_conv True
# block7b_expand_bn True
# block7b_expand_activation True
# block7b_dwconv2 True
# block7b_bn True
# block7b_activation True
# block7b_se_squeeze True
# block7b_se_reshape True
# block7b_se_reduce True
# block7b_se_expand True
# block7b_se_excite True
# block7b_project_conv True
# block7b_project_bn True
# block7b_drop True
# block7b_add True
# block7c_expand_conv True
# block7c_expand_bn True
# block7c_expand_activation True
# block7c_dwconv2 True
# block7c_bn True
# block7c_activation True
# block7c_se_squeeze True
# block7c_se_reshape True
# block7c_se_reduce True
# block7c_se_expand True
# block7c_se_excite True
# block7c_project_conv True
# block7c_project_bn True
# block7c_drop True
# block7c_add True
# block7d_expand_conv True
# block7d_expand_bn True
# block7d_expand_activation True
# block7d_dwconv2 True
# block7d_bn True
# block7d_activation True
# block7d_se_squeeze True
# block7d_se_reshape True
# block7d_se_reduce True
# block7d_se_expand True
# block7d_se_excite True
# block7d_project_conv True
# block7d_project_bn True
# block7d_drop True
# block7d_add True
# block7e_expand_conv True
# block7e_expand_bn True
# block7e_expand_activation True
# block7e_dwconv2 True
# block7e_bn True
# block7e_activation True
# block7e_se_squeeze True
# block7e_se_reshape True
# block7e_se_reduce True
# block7e_se_expand True
# block7e_se_excite True
# block7e_project_conv True
# block7e_project_bn True
# block7e_drop True
# block7e_add True
# top_conv True
# top_bn True
# top_activation True

# %%
conv_base_EffiecientNetv2M.summary()
# Out:
# Model: "efficientnetv2-m"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 255, 255, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 255, 255, 3)          0         ['input_1[0][0]']
#
#  stem_conv (Conv2D)          (None, 128, 128, 24)         648       ['rescaling[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 128, 128, 24)         96        ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 128, 128, 24)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 128, 128, 24)         5184      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 128, 128, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 128, 128, 24)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 128, 128, 24)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 128, 128, 24)         5184      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 128, 128, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 128, 128, 24)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 128, 128, 24)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 128, 128, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block1c_project_conv (Conv  (None, 128, 128, 24)         5184      ['block1b_add[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 128, 128, 24)         96        ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_project_activation  (None, 128, 128, 24)         0         ['block1c_project_bn[0][0]']
#   (Activation)
#
#  block1c_drop (Dropout)      (None, 128, 128, 24)         0         ['block1c_project_activation[0
#                                                                     ][0]']
#
#  block1c_add (Add)           (None, 128, 128, 24)         0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 64, 64, 96)           20736     ['block1c_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 64, 64, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 64, 64, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 64, 64, 48)           4608      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 64, 64, 192)          82944     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 64, 64, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 64, 64, 48)           9216      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 64, 64, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 64, 64, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 64, 64, 192)          82944     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 64, 64, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 64, 64, 48)           9216      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 64, 64, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 64, 64, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 64, 64, 192)          82944     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 64, 64, 192)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 64, 64, 48)           9216      ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 64, 64, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 64, 64, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 64, 64, 192)          82944     ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 64, 64, 192)          768       ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 64, 64, 192)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_project_conv (Conv  (None, 64, 64, 48)           9216      ['block2e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2e_project_bn (BatchN  (None, 64, 64, 48)           192       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (Dropout)      (None, 64, 64, 48)           0         ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)           (None, 64, 64, 48)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 32, 32, 192)          82944     ['block2e_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 32, 32, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 32, 32, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 32, 32, 80)           15360     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 32, 32, 80)           320       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 32, 32, 320)          230400    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 32, 32, 320)          1280      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 32, 32, 320)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 32, 32, 80)           25600     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 32, 32, 80)           320       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 32, 32, 80)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 32, 32, 80)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 32, 32, 320)          230400    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 32, 32, 320)          1280      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 32, 32, 320)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 32, 32, 80)           25600     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 32, 32, 80)           320       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 32, 32, 80)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 32, 32, 80)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 32, 32, 320)          230400    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 32, 32, 320)          1280      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 32, 32, 320)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 32, 32, 80)           25600     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 32, 32, 80)           320       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 32, 32, 80)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 32, 32, 80)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2  (None, 32, 32, 320)          230400    ['block3d_add[0][0]']
#  D)
#
#  block3e_expand_bn (BatchNo  (None, 32, 32, 320)          1280      ['block3e_expand_conv[0][0]']
#  rmalization)
#
#  block3e_expand_activation   (None, 32, 32, 320)          0         ['block3e_expand_bn[0][0]']
#  (Activation)
#
#  block3e_project_conv (Conv  (None, 32, 32, 80)           25600     ['block3e_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3e_project_bn (BatchN  (None, 32, 32, 80)           320       ['block3e_project_conv[0][0]']
#  ormalization)
#
#  block3e_drop (Dropout)      (None, 32, 32, 80)           0         ['block3e_project_bn[0][0]']
#
#  block3e_add (Add)           (None, 32, 32, 80)           0         ['block3e_drop[0][0]',
#                                                                      'block3d_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 32, 32, 320)          25600     ['block3e_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 32, 32, 320)          1280      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 32, 32, 320)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 16, 16, 320)          2880      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 16, 16, 320)          1280      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 16, 16, 320)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 320)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 320)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 20)             6420      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 320)            6720      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 16, 16, 320)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 16, 16, 160)          51200     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 16, 16, 160)          640       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 16, 16, 640)          102400    ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 16, 16, 640)          2560      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 16, 16, 640)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 16, 16, 640)          5760      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 16, 16, 640)          2560      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 16, 16, 640)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 640)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 16, 16, 640)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 16, 16, 160)          102400    ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 16, 16, 160)          640       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 16, 16, 160)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 16, 16, 160)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 16, 16, 640)          102400    ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 16, 16, 640)          2560      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 16, 16, 640)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 16, 16, 640)          5760      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 16, 16, 640)          2560      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 16, 16, 640)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 640)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 16, 16, 640)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 16, 16, 160)          102400    ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 16, 16, 160)          640       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 16, 16, 160)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 16, 16, 160)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 16, 16, 640)          102400    ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 16, 16, 640)          2560      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 16, 16, 640)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 16, 16, 640)          5760      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 16, 16, 640)          2560      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 16, 16, 640)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 640)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 16, 16, 640)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 16, 16, 160)          102400    ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 16, 16, 160)          640       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 16, 16, 160)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 16, 16, 160)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 16, 16, 640)          102400    ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 16, 16, 640)          2560      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 16, 16, 640)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 16, 16, 640)          5760      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 16, 16, 640)          2560      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 16, 16, 640)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 640)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 16, 16, 640)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 16, 16, 160)          102400    ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 16, 16, 160)          640       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 16, 16, 160)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 16, 16, 160)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2  (None, 16, 16, 640)          102400    ['block4e_add[0][0]']
#  D)
#
#  block4f_expand_bn (BatchNo  (None, 16, 16, 640)          2560      ['block4f_expand_conv[0][0]']
#  rmalization)
#
#  block4f_expand_activation   (None, 16, 16, 640)          0         ['block4f_expand_bn[0][0]']
#  (Activation)
#
#  block4f_dwconv2 (Depthwise  (None, 16, 16, 640)          5760      ['block4f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4f_bn (BatchNormaliza  (None, 16, 16, 640)          2560      ['block4f_dwconv2[0][0]']
#  tion)
#
#  block4f_activation (Activa  (None, 16, 16, 640)          0         ['block4f_bn[0][0]']
#  tion)
#
#  block4f_se_squeeze (Global  (None, 640)                  0         ['block4f_activation[0][0]']
#  AveragePooling2D)
#
#  block4f_se_reshape (Reshap  (None, 1, 1, 640)            0         ['block4f_se_squeeze[0][0]']
#  e)
#
#  block4f_se_reduce (Conv2D)  (None, 1, 1, 40)             25640     ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)  (None, 1, 1, 640)            26240     ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multipl  (None, 16, 16, 640)          0         ['block4f_activation[0][0]',
#  y)                                                                  'block4f_se_expand[0][0]']
#
# ...
#  block7b_se_squeeze (Global  (None, 3072)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 8, 8, 3072)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 8, 8, 512)            1572864   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 8, 8, 512)            2048      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 8, 8, 512)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 8, 8, 512)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 8, 8, 3072)           1572864   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 8, 8, 3072)           12288     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 8, 8, 3072)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv2 (Depthwise  (None, 8, 8, 3072)           27648     ['block7c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7c_bn (BatchNormaliza  (None, 8, 8, 3072)           12288     ['block7c_dwconv2[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 8, 8, 3072)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3072)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 8, 8, 3072)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 8, 8, 512)            1572864   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 8, 8, 512)            2048      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (Dropout)      (None, 8, 8, 512)            0         ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)           (None, 8, 8, 512)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2  (None, 8, 8, 3072)           1572864   ['block7c_add[0][0]']
#  D)
#
#  block7d_expand_bn (BatchNo  (None, 8, 8, 3072)           12288     ['block7d_expand_conv[0][0]']
#  rmalization)
#
#  block7d_expand_activation   (None, 8, 8, 3072)           0         ['block7d_expand_bn[0][0]']
#  (Activation)
#
#  block7d_dwconv2 (Depthwise  (None, 8, 8, 3072)           27648     ['block7d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7d_bn (BatchNormaliza  (None, 8, 8, 3072)           12288     ['block7d_dwconv2[0][0]']
#  tion)
#
#  block7d_activation (Activa  (None, 8, 8, 3072)           0         ['block7d_bn[0][0]']
#  tion)
#
#  block7d_se_squeeze (Global  (None, 3072)                 0         ['block7d_activation[0][0]']
#  AveragePooling2D)
#
#  block7d_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7d_se_squeeze[0][0]']
#  e)
#
#  block7d_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multipl  (None, 8, 8, 3072)           0         ['block7d_activation[0][0]',
#  y)                                                                  'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv  (None, 8, 8, 512)            1572864   ['block7d_se_excite[0][0]']
#  2D)
#
#  block7d_project_bn (BatchN  (None, 8, 8, 512)            2048      ['block7d_project_conv[0][0]']
#  ormalization)
#
#  block7d_drop (Dropout)      (None, 8, 8, 512)            0         ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)           (None, 8, 8, 512)            0         ['block7d_drop[0][0]',
#                                                                      'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2  (None, 8, 8, 3072)           1572864   ['block7d_add[0][0]']
#  D)
#
#  block7e_expand_bn (BatchNo  (None, 8, 8, 3072)           12288     ['block7e_expand_conv[0][0]']
#  rmalization)
#
#  block7e_expand_activation   (None, 8, 8, 3072)           0         ['block7e_expand_bn[0][0]']
#  (Activation)
#
#  block7e_dwconv2 (Depthwise  (None, 8, 8, 3072)           27648     ['block7e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block7e_bn (BatchNormaliza  (None, 8, 8, 3072)           12288     ['block7e_dwconv2[0][0]']
#  tion)
#
#  block7e_activation (Activa  (None, 8, 8, 3072)           0         ['block7e_bn[0][0]']
#  tion)
#
#  block7e_se_squeeze (Global  (None, 3072)                 0         ['block7e_activation[0][0]']
#  AveragePooling2D)
#
#  block7e_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7e_se_squeeze[0][0]']
#  e)
#
#  block7e_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multipl  (None, 8, 8, 3072)           0         ['block7e_activation[0][0]',
#  y)                                                                  'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv  (None, 8, 8, 512)            1572864   ['block7e_se_excite[0][0]']
#  2D)
#
#  block7e_project_bn (BatchN  (None, 8, 8, 512)            2048      ['block7e_project_conv[0][0]']
#  ormalization)
#
#  block7e_drop (Dropout)      (None, 8, 8, 512)            0         ['block7e_project_bn[0][0]']
#
#  block7e_add (Add)           (None, 8, 8, 512)            0         ['block7e_drop[0][0]',
#                                                                      'block7d_add[0][0]']
#
#  top_conv (Conv2D)           (None, 8, 8, 1280)           655360    ['block7e_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 8, 8, 1280)           5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 8, 8, 1280)           0         ['top_bn[0][0]']
#  )
#
# ==================================================================================================
# Total params: 53150388 (202.75 MB)
# Trainable params: 52858356 (201.64 MB)
# Non-trainable params: 292032 (1.11 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# # Adding fully connected and output layer to EfficientNetV2M model
#
# 1] We are storing the output of last convolutional layer to feed fully connected layer.
# before feeding the output of last convolutional layer to fully connected layer we need to onvert 3d tensor to 1d tensor as fully connected layer accepts input in 1d form. We are using **GlobalAveragePooling2D** to flatten the output of last convolutional layer.
#
# GlobalAveragePooling2D() function works same as flatten(), only difference is flatten() maintain all the features of convolutional layer and GlobalAveragePooling2D() takes avarage of all the feature maps
# For tensor shape like (8, 8, 1280) it will take average of 8X8 features maps (1280) , which will convert tesnsor into (batch_szie X no_of_feature_maps) i.e 4x1280 in our case.
#
# **GlobalAveragePooling2D** helps to reduce intense tensor shape which can cause overfitting to our model.
#
#
# 2] We are adding dense layers to create fully connected network after flattenning tensor shape using GlobalAveragePooling2D layer.
#
# 3] **Dropout layer**: I have used dropout layer to overcome overfitting in a model. Dropout layers unuses no. of neurons for that epoch randomly, this helps to focus on each and every pattern instead of some fixed patterns, this reduce dependancy of neurons from previous layers, introduce different neural architecture by dropping neurons randomly.
#
#
# 4] **Batch normalization**: Batch normalization helps to speed up and stabilize training of any neural network model.
# In batch normalization we are trying to reduce the effect of "Internal Covariate Shift" which causes delay in convergenece of model towards global minima.
# Internal Covariate Shift is the change in the distribution of network activations due to the chang in network parameter during training.
#
# In deep neural network activation of neurons depends upon w and b parameter of network which keeps changing throughout the training of model which causes change in distribution. For this we have to keep learnin rate (n) bery slow which causes slow training.
#
# Batch-normalization is works only with mini-batch and its applied before relu i.e non-linear activation function.
# It normalizes the activation of neurons by calaculating mean and variance of mini-batch data and apply stardard deviation. It uses Gamma and beta learnable paraetrs which apply scale and shift method to input of activations function.
#
# 5] **Activation fucntion**: we are using **elu** activation function for all the fully connected networks hidden layers and softmax activation fucntion for output layer as we have to predict 7 categories of emotions.

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten,BatchNormalization, GlobalAveragePooling2D, GlobalMaxPooling2D
from keras.models import Model


x = conv_base_EffiecientNetv2M.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(3000, activation='elu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(2024, activation='elu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(1050, activation='elu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(1000, activation='elu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(562, activation='elu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(200, activation='elu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
x = Dense(100, activation='elu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(7, activation='softmax')(x)

# this is the model we will train
model_Efficientnetv2M = Model(inputs=conv_base_EffiecientNetv2M.input, outputs=predictions)

# %% [markdown]
# # Model Callback
#
# **ModelCheckpoint :** We need to save weights of model whle training for future use, for this we need to create modelcheckpoint. Here, I am monitoring val_loss , It will overwrite the filepath of saved model by each best model. verbose=1 dispalys message when callback takes an action.
#
# **earlystop :** Early stopping is uesed to stop training of model, when model tries to overfit or model loss is not decreasing at all. min_delta is  the amount of change in loss which is qualify as an model improvement. **patience** is no. of epochs without ay improvement in model accuracy after thattraining will stopped.
#
# **ReduceLROnPlateau :** Reduce learning rate when monitored quantity is not improving. **Patience** is no.of epochs with no improvement after that learning rate will get decrease. **factor** by which learning rate will get reduced. **min_delta** Threshold for measuring the new optimum, to only focus on significant changes.

# %%
checkpoint_M = ModelCheckpoint('/kaggle/working/checkpoints/Emotion_Detection_Model_Efficient_v2M.keras',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=10,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)


callbacks_v2M = [earlystop,checkpoint_M,reduce_lr]

# %% [markdown]
# **Complie model before trainning**

# %%
model_Efficientnetv2M.compile(optimizer=Adam(1e-5) , loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Training Model**

# %%
history_efficientv2M = model_Efficientnetv2M.fit(train_generator,epochs=50, validation_data=validation_generator, callbacks=callbacks_v2M)

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history_efficientv2M, 'accuracy')

# %%
from keras.models import load_model

# %% [markdown]
# # Loading saved model for testing purpose

# %%
classifier = load_model('/kaggle/input/emotion_detection_model/keras/emotion_detection/1/Emotion_Detection_Model_v2M.keras', compile=True)

# %% [markdown]
# # Prediction on test data

# %%
y_pred = classifier.predict(test_generator)
# Out:
# 5746/5746 [==============================] - 146s 24ms/step

# %%
output = classifier.evaluate(test_generator)
# Out:
# 5746/5746 [==============================] - 162s 28ms/step - loss: 1.0166 - accuracy: 0.6272
